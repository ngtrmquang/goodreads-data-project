# %%
import duckdb

con = duckdb.connect()

# %%
books_path = r"C:\Users\Quang\Documents\USTH\FundDS\goodreads_books.json.gz"
authors_path = r"C:\Users\Quang\Documents\USTH\FundDS\goodreads_book_authors.json.gz"
works_path = r"C:\Users\Quang\Documents\USTH\FundDS\goodreads_book_works.json.gz"
genres_path = r"C:\Users\Quang\Documents\USTH\FundDS\goodreads_book_genres_initial.json.gz"
interactions_path = r"C:\Users\Quang\Documents\USTH\FundDS\goodreads_interactions.csv"

# %%
con.sql(f"""
    SELECT *
    FROM read_json_auto('{books_path}')
    LIMIT 5
""")
# Out:
# ┌────────────┬────────────────────┬───────────┬──────────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
con.sql(f"""
    SELECT *
    FROM read_json_auto('{authors_path}')
    LIMIT 5
""")
# Out:
# ┌────────────────┬───────────┬────────────────────┬──────────────────┬───────────────┐
# │ average_rating │ author_id │ text_reviews_count │       name       │ ratings_count │
# │    varchar     │  varchar  │      varchar       │     varchar      │    varchar    │
# ├────────────────┼───────────┼────────────────────┼──────────────────┼───────────────┤
# │ 3.98           │ 604031    │ 7                  │ Ronald J. Fields │ 49            │
# │ 4.08           │ 626222    │ 28716              │ Anita Diamant    │ 546796        │
# │ 3.92           │ 10333     │ 5075               │ Barbara Hambly   │ 122118        │
# │ 3.68           │ 9212      │ 36262              │ Jennifer Weiner  │ 888522        │
# │ 3.82           │ 149918    │ 96                 │ Nigel Pennick    │ 1740          │
# └────────────────┴───────────┴────────────────────┴──────────────────┴───────────────┘

# %%
con.sql(f"""
    SELECT *
    FROM read_json_auto('{works_path}')
    LIMIT 5
""")
# Out:
# ┌─────────────┬───────────────┬────────────────────────────┬───────────────────────────────────┬────────────────────┬──────────────┬───────────────────────────┬──────────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────┬────────────────────────────┬──────────────────────────┬──────────────────────┬───────────────┬────────────┬─────────────┬─────────┐
# │ books_count │ reviews_count │ original_publication_month │ default_description_language_code │ text_reviews_count │ best_book_id │ original_publication_year │                            original_title                            │                   rating_dist                    │ default_chaptering_book_id │ original_publication_day │ original_language_id │ ratings_count │ media_type │ ratings_sum │ work_id │
# ...

# %%
con.sql(f"""
    SELECT *
    FROM read_json_auto('{genres_path}')
    LIMIT 5
""")
# Out:
# ┌─────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ book_id │                                                                                                                                  genres                                                                                                                                  │
# │ varchar │ struct("history, historical fiction, biography" hugeint, fiction hugeint, "fantasy, paranormal" hugeint, "mystery, thriller, crime" hugeint, poetry hugeint, romance hugeint, "non-fiction" hugeint, children hugeint, "young-adult" hugeint, "comics, graphic" hugeint) │
# ...

# %%
con.sql(f"""
    SELECT *
    FROM read_csv_auto('{interactions_path}')
    LIMIT 10
""")
# Out:
# ┌─────────┬─────────┬─────────┬────────┬─────────────┐
# │ user_id │ book_id │ is_read │ rating │ is_reviewed │
# │  int64  │  int64  │  int64  │ int64  │    int64    │
# ├─────────┼─────────┼─────────┼────────┼─────────────┤
# │       0 │     948 │       1 │      5 │           0 │
# │       0 │     947 │       1 │      5 │           1 │
# │       0 │     946 │       1 │      5 │           0 │
# │       0 │     945 │       1 │      5 │           0 │
# │       0 │     944 │       1 │      5 │           0 │
# │       0 │     943 │       1 │      5 │           0 │
# │       0 │     942 │       1 │      5 │           0 │
# │       0 │     941 │       1 │      5 │           0 │
# │       0 │     940 │       1 │      5 │           0 │
# │       0 │     939 │       1 │      5 │           1 │
# └─────────┴─────────┴─────────┴────────┴─────────────┘
#   10 rows                                  5 columns

# %%
con.sql(f"""
    SELECT COUNT(*) AS total_books
    FROM read_json_auto('{books_path}')
""")
# Out:
# ┌─────────────┐
# │ total_books │
# │    int64    │
# ├─────────────┤
# │     2360655 │
# └─────────────┘

# %%
con.sql(f"""
    SELECT COUNT(*) AS total_works
    FROM read_json_auto('{works_path}')
""")
# Out:
# ┌─────────────┐
# │ total_works │
# │    int64    │
# ├─────────────┤
# │     1521962 │
# └─────────────┘

# %%
con.sql(f"""
    SELECT COUNT(*) AS total_books
    FROM read_csv_auto('{interactions_path}')
""")
# Out:
# ┌─────────────┐
# │ total_books │
# │    int64    │
# ├─────────────┤
# │   228648342 │
# └─────────────┘
