# %%
import duckdb

con = duckdb.connect()

# %%
books_path = ("C:/Users/Quang/Documents/USTH/FundDS/goodreads_books.json.gz")
authors_path = ("C:/Users/Quang/Documents/USTH/FundDS/goodreads_book_authors.json.gz")
works_path = ("C:/Users/Quang/Documents/USTH/FundDS/goodreads_book_works.json.gz")
genres_path = ("C:/Users/Quang/Documents/USTH/FundDS/goodreads_book_genres_initial.json.gz")
interactions_path = ("C:/Users/Quang/Documents/USTH/FundDS/goodreads_interactions.csv")

# %%
con.sql("""
    DESCRIBE
    SELECT * 
    FROM read_json_auto($1)
    """,
    params=[books_path],
).show()
# Out:
# ┌──────────────────────┬─────────────────────────────────────────┬─────────┬─────────┬─────────┬─────────┐
# │     column_name      │               column_type               │  null   │   key   │ default │  extra  │
# │       varchar        │                 varchar                 │ varchar │ varchar │ varchar │ varchar │
# ├──────────────────────┼─────────────────────────────────────────┼─────────┼─────────┼─────────┼─────────┤
# │ isbn                 │ VARCHAR                                 │ YES     │ NULL    │ NULL    │ NULL    │
# │ text_reviews_count   │ VARCHAR                                 │ YES     │ NULL    │ NULL    │ NULL    │
# │ series               │ VARCHAR[]                               │ YES     │ NULL    │ NULL    │ NULL    │
# │ country_code         │ VARCHAR                                 │ YES     │ NULL    │ NULL    │ NULL    │
# │ language_code        │ VARCHAR                                 │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
con.sql("""
    DESCRIBE
    SELECT * 
    FROM read_json_auto($1)
    """,
    params=[works_path],
).show()
# Out:
# ┌───────────────────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │            column_name            │ column_type │  null   │   key   │ default │  extra  │
# │              varchar              │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├───────────────────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ books_count                       │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ reviews_count                     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ original_publication_month        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ default_description_language_code │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ text_reviews_count                │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ best_book_id                      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
con.sql("""
    DESCRIBE
    SELECT * 
    FROM read_json_auto($1)
    """,
    params=[authors_path],
).show()
# Out:
# ┌────────────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │    column_name     │ column_type │  null   │   key   │ default │  extra  │
# │      varchar       │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├────────────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ average_rating     │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ author_id          │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ text_reviews_count │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ name               │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ratings_count      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# └────────────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
con.sql("""
    DESCRIBE
    SELECT * 
    FROM read_json_auto($1)
    """,
    params=[genres_path],
).show()
# Out:
# ┌─────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name │                                                                                                                               column_type                                                                                                                                │  null   │   key   │ default │  extra  │
# │   varchar   │                                                                                                                                 varchar                                                                                                                                  │ varchar │ varchar │ varchar │ varchar │
# ...

# %%
con.sql("""
    DESCRIBE
    SELECT * 
    FROM read_csv_auto($1)
    """,
    params=[interactions_path],
).show()
# Out:
# ┌─────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name │ column_type │  null   │   key   │ default │  extra  │
# │   varchar   │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ user_id     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ book_id     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_read     │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ rating      │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# │ is_reviewed │ BIGINT      │ YES     │ NULL    │ NULL    │ NULL    │
# └─────────────┴─────────────┴─────────┴─────────┴─────────┴─────────┘

# %%
con.sql("""
    SELECT *
    FROM read_json_auto($1)
    LIMIT 5
    """,
    params=[books_path],
).show()
# Out:
# ┌────────────┬────────────────────┬───────────┬──────────────┬───────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
con.sql("""
    SELECT *
    FROM read_json_auto($1)
    LIMIT 5
    """,
    params=[authors_path],
).df()
# Out:
#   average_rating author_id text_reviews_count              name ratings_count
# 0           3.98    604031                  7  Ronald J. Fields            49
# 1           4.08    626222              28716     Anita Diamant        546796
# 2           3.92     10333               5075    Barbara Hambly        122118
# 3           3.68      9212              36262   Jennifer Weiner        888522
# 4           3.82    149918                 96     Nigel Pennick          1740

# %%
con.sql("""
    SELECT *
    FROM read_json_auto($1)
    LIMIT 5
    """,
    params=[works_path],
).df()
# Out:
#   books_count reviews_count original_publication_month  \
# 0           1             6                          8
# 1          22         10162
# 2           2           268
# 3          38         89252                          7
# 4           2            49
#
#   default_description_language_code text_reviews_count best_book_id  \
# 0                                                    1      5333265
# 1                                                  741        25717
# 2                                                    7      7327624
# 3                                                 3504      6066819
# 4                                                    5       287140
#
#   original_publication_year  \
# 0                      1984
# 1                      2001
# 2                      1987
# 3                      2009
# 4                      1990
#
#                                       original_title  \
# 0                       W. C. Fields: A Life on Film
# ...

# %%
con.sql("""
    SELECT *
    FROM read_json_auto($1)
    LIMIT 5
    """,
    params=[genres_path],
).show()
# Out:
# ┌─────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ book_id │                                                                                                                                  genres                                                                                                                                  │
# │ varchar │ struct("history, historical fiction, biography" hugeint, fiction hugeint, "fantasy, paranormal" hugeint, "mystery, thriller, crime" hugeint, poetry hugeint, romance hugeint, "non-fiction" hugeint, children hugeint, "young-adult" hugeint, "comics, graphic" hugeint) │
# ...

# %%
con.sql("""
    SELECT *
    FROM read_csv_auto($1)
    LIMIT 5
    """,
    params=[interactions_path],
).df()
# Out:
#    user_id  book_id  is_read  rating  is_reviewed
# 0        0      948        1       5            0
# 1        0      947        1       5            1
# 2        0      946        1       5            0
# 3        0      945        1       5            0
# 4        0      944        1       5            0

# %%
con.sql("""
    SELECT COUNT(*) AS total_books
    FROM read_json_auto($1)
    """,
    params=[books_path],
).show()
# Out:
# ┌─────────────┐
# │ total_books │
# │    int64    │
# ├─────────────┤
# │     2360655 │
# └─────────────┘

# %%
con.sql("""
    SELECT COUNT(*) AS total_books
    FROM read_json_auto($1)
    """,
    params=[works_path],
).show()
# Out:
# ┌─────────────┐
# │ total_books │
# │    int64    │
# ├─────────────┤
# │     1521962 │
# └─────────────┘

# %%
con.sql("""
    SELECT COUNT(*) AS total_books
    FROM read_json_auto($1)
    """,
    params=[interactions_path],
).show()
# Out:
# ┌─────────────┐
# │ total_books │
# │    int64    │
# ├─────────────┤
# │   228648342 │
# └─────────────┘
