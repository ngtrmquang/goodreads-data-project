# %%
import pandas as pd

# %%
df_user = pd.read_parquet(r"C:\Users\Quang\Documents\USTH\FundDS\dataset\mart_user_ratings.parquet")

print(df_user.shape)
# Out:
# (5000000, 12)

# %%
df_user.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   user_id                str
#  1   book_id                int32
#  2   book_title             str
#  3   user_rating            int32
#  4   book_author_names      object
#  5   book_average_rating    float32
#  6   book_publication_year  float64
#  7   book_genre_1           str
#  8   book_genre_2           str
#  9   book_genre_3           str
#  10  book_genre_4           str
#  11  book_genre_5           str
# dtypes: float32(1), float64(1), int32(2), object(1), str(7)
# memory usage: 812.5+ MB

# %%
df_user
# Out:
#                                   user_id   book_id  \
# 0        733d1a864a29c2a337e4c4862a865dcb  18071590
# 1        8331156ffec5f492e4a10a85f4aaac85    298230
# 2        73fe252243e1a82acc7b407f12114d91     73070
# 3        b0579d39685bf9ea52d519ba28b6a1d2   6068551
# 4        20bfb3356b796552cdbb9115872e7e50     17125
# ...                                   ...       ...
# 4999995  18f98af6dc0941b6ebc86b8dd57865ea  30302076
# 4999996  72e0e5d0aa51dc7e5f6196f873ac3ebb  18068635
# 4999997  c4b5fd2c733469fc3e83e86ccfd6ce37  11947829
# 4999998  b8754de71b163d2022223568b03fcdd2  18516961
# 4999999  4314245a924717a6129693eab7f99779     18405
#
#                           book_title  user_rating  \
# 0                      Me Before You            3
# 1                         Agnes Grey            3
# 2                   It Had to Be You            0
# 3                             Shiver            0
# 4        Odin den' Ivana Denisovicha            0
# ...
